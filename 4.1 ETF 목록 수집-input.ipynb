# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.

url = "https://finance.naver.com/sise/etf.nhn"

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)

# 그냥 url 넣었을 떄 안나온다면 xhr, js doc에 requets url로 찾아보기 

#url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc&_callback=window.__jindo2_callback._5469"
#그냥 하면 error -> request 통해서
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gk/575ywhys2fl6cy6yy62tjl8h0000gn/T/ipykernel_40483/3876705159.py in <module>
# ----> 1 pd.read_html(url)
#       2
#       3 # 그냥 url 넣었을 떄 안나온다면 xhr, js doc에 requets url로 찾아보기
#       4
#       5 url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc&_callback=window.__jindo2_callback._5469"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.

url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc&_callback=window.__jindo2_callback._5469"

response = requests.get(url)

response.text

# response.json()--> error 
## 'window.__jindo2_callback. -> error  0-> url callbakc 제거 

url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"


response = requests.get(url)

response.json()

## 해결!
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 39425,
#     'risefall': '5',
#     'changeVal': -175,
#     'changeRate': -0.44,
#     'nav': 39456.0,
#     'threeMonthEarnRate': -2.0239,
#     'quant': 1850963,
#     'amonut': 73236,
#     'marketSum': 53815},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 20100,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -1.11,
#     'nav': None,
#     'threeMonthEarnRate': 15.8779,
#     'quant': 3216944,
#     'amonut': 65122,
#     'marketSum': 30287},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 39445,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -0.47,
#     'nav': 39488.0,
#     'threeMonthEarnRate': -1.9861,
#     'quant': 251033,
#     'amonut': 9952,
#     'marketSum': 22188},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 2225,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 1.14,
#     'nav': 2222.0,
#     'threeMonthEarnRate': 2.3255,
#     'quant': 128211523,
#     'amonut': 282593,
#     'marketSum': 20759},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 102990,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 102986.0,
#     'threeMonthEarnRate': 0.1263,
#     'quant': 34183,
#     'amonut': 3520,
#     'marketSum': 19435},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 23525,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -0.99,
#     'nav': 23589.0,
#     'threeMonthEarnRate': -4.7696,
#     'quant': 12726430,
#     'amonut': 301683,
#     'marketSum': 18867},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 86770,
#     'risefall': '5',
#     'changeVal': -260,
#     'changeRate': -0.3,
#     'nav': None,
#     'threeMonthEarnRate': 9.3712,
#     'quant': 238589,
#     'amonut': 20700,
#     'marketSum': 16556},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 12680,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.59,
#     'nav': 12694.0,
#     'threeMonthEarnRate': -1.8847,
#     'quant': 297245,
#     'amonut': 3804,
#     'marketSum': 16028},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 9825,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.71,
#     'nav': 9835.0,
#     'threeMonthEarnRate': -4.8101,
#     'quant': 150767,
#     'amonut': 1489,
#     'marketSum': 15848},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100420,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 100422.0,
#     'threeMonthEarnRate': 0.1595,
#     'quant': 14406,
#     'amonut': 1446,
#     'marketSum': 15519},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 107175,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.05,
#     'nav': 107232.0,
#     'threeMonthEarnRate': -2.4828,
#     'quant': 3735,
#     'amonut': 400,
#     'marketSum': 15068},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 15925,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.22,
#     'nav': 15943.0,
#     'threeMonthEarnRate': -2.445,
#     'quant': 88,
#     'amonut': 1,
#     'marketSum': 13918},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 13615,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.84,
#     'nav': 13638.0,
#     'threeMonthEarnRate': -2.8653,
#     'quant': 233807,
#     'amonut': 3205,
#     'marketSum': 13663},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 12930,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.58,
#     'nav': 12956.0,
#     'threeMonthEarnRate': -2.0339,
#     'quant': 30287,
#     'amonut': 393,
#     'marketSum': 12723},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103280,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 103285.0,
#     'threeMonthEarnRate': 0.1066,
#     'quant': 6824,
#     'amonut': 704,
#     'marketSum': 12588},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4050,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.5,
#     'nav': 4056.0,
#     'threeMonthEarnRate': 1.3836,
#     'quant': 22624040,
#     'amonut': 91254,
#     'marketSum': 11502},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 39530,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -0.47,
#     'nav': 39578.0,
#     'threeMonthEarnRate': -2.0085,
#     'quant': 38779,
#     'amonut': 1535,
#     'marketSum': 10970},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 24415,
#     'risefall': '2',
#     'changeVal': 350,
#     'changeRate': 1.45,
#     'nav': 24422.0,
#     'threeMonthEarnRate': 18.576,
#     'quant': 2540285,
#     'amonut': 61427,
#     'marketSum': 10755},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 24005,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 0.8,
#     'nav': 24007.0,
#     'threeMonthEarnRate': 11.7026,
#     'quant': 1738062,
#     'amonut': 41458,
#     'marketSum': 10466},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 14010,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.14,
#     'nav': None,
#     'threeMonthEarnRate': 6.6636,
#     'quant': 426953,
#     'amonut': 5987,
#     'marketSum': 10339},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 13135,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.64,
#     'nav': None,
#     'threeMonthEarnRate': 11.8443,
#     'quant': 1279690,
#     'amonut': 16824,
#     'marketSum': 9917},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 36840,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.43,
#     'nav': 36838.0,
#     'threeMonthEarnRate': 2.3371,
#     'quant': 165626,
#     'amonut': 6116,
#     'marketSum': 9350},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 12630,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -1.79,
#     'nav': None,
#     'threeMonthEarnRate': 16.8559,
#     'quant': 819533,
#     'amonut': 10401,
#     'marketSum': 7533},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 12275,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.93,
#     'nav': None,
#     'threeMonthEarnRate': 19.7101,
#     'quant': 1883821,
#     'amonut': 23153,
#     'marketSum': 7377},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 40075,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -0.53,
#     'nav': 40150.0,
#     'threeMonthEarnRate': -2.185,
#     'quant': 33285,
#     'amonut': 1333,
#     'marketSum': 7073},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 20870,
#     'risefall': '5',
#     'changeVal': -260,
#     'changeRate': -1.23,
#     'nav': 20905.0,
#     'threeMonthEarnRate': -1.949,
#     'quant': 368520,
#     'amonut': 7715,
#     'marketSum': 6939},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 39660,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -0.55,
#     'nav': 39719.0,
#     'threeMonthEarnRate': -1.9425,
#     'quant': 127597,
#     'amonut': 5065,
#     'marketSum': 6861},
#    {'itemcode': '233740',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150 레버리지',
#     'nowVal': 16025,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.79,
#     'nav': 16209.0,
#     'threeMonthEarnRate': 6.2834,
#     'quant': 6802009,
#     'amonut': 107998,
#     'marketSum': 6811},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 18685,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -0.8,
#     'nav': 18702.0,
#     'threeMonthEarnRate': 2.8392,
#     'quant': 910,
#     'amonut': 17,
#     'marketSum': 6689},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 39400,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -0.57,
#     'nav': 39456.0,
#     'threeMonthEarnRate': -2.0081,
#     'quant': 171,
#     'amonut': 6,
#     'marketSum': 6225},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 39440,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -0.57,
#     'nav': 39500.0,
#     'threeMonthEarnRate': -1.9843,
#     'quant': 10221,
#     'amonut': 403,
#     'marketSum': 6212},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 17620,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.11,
#     'nav': 17654.0,
#     'threeMonthEarnRate': 2.2958,
#     'quant': 488376,
#     'amonut': 8594,
#     'marketSum': 5550},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4145,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.48,
#     'nav': 4150.0,
#     'threeMonthEarnRate': -5.2333,
#     'quant': 20560443,
#     'amonut': 85684,
#     'marketSum': 5505},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 14110,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.18,
#     'nav': None,
#     'threeMonthEarnRate': 6.4545,
#     'quant': 123771,
#     'amonut': 1748,
#     'marketSum': 5192},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 47030,
#     'risefall': '5',
#     'changeVal': -255,
#     'changeRate': -0.54,
#     'nav': 47083.0,
#     'threeMonthEarnRate': -1.9899,
#     'quant': 1619,
#     'amonut': 76,
#     'marketSum': 4985},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 30625,
#     'risefall': '5',
#     'changeVal': -255,
#     'changeRate': -0.83,
#     'nav': None,
#     'threeMonthEarnRate': 12.1278,
#     'quant': 102574,
#     'amonut': 3142,
#     'marketSum': 4885},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 30105,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.18,
#     'nav': 30110.0,
#     'threeMonthEarnRate': -3.0537,
#     'quant': 3993,
#     'amonut': 120,
#     'marketSum': 3793},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 104690,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 104688.0,
#     'threeMonthEarnRate': 0.1434,
#     'quant': 2784433,
#     'amonut': 291491,
#     'marketSum': 3767},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 98850,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.11,
#     'nav': 98827.0,
#     'threeMonthEarnRate': -2.3535,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 3741},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 12080,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12096.0,
#     'threeMonthEarnRate': -10.4854,
#     'quant': 487921,
#     'amonut': 5894,
#     'marketSum': 3733},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 21350,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.12,
#     'nav': None,
#     'threeMonthEarnRate': 4.6767,
#     'quant': 85527,
#     'amonut': 1823,
#     'marketSum': 3565},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7585,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.66,
#     'nav': 7614.0,
#     'threeMonthEarnRate': 5.5322,
#     'quant': 1456600,
#     'amonut': 11086,
#     'marketSum': 3531},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 24115,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.52,
#     'nav': 24153.0,
#     'threeMonthEarnRate': -2.0607,
#     'quant': 8500,
#     'amonut': 204,
#     'marketSum': 3497},
#    {'itemcode': '400970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn메타버스',
#     'nowVal': 13120,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.76,
#     'nav': 13142.0,
#     'threeMonthEarnRate': None,
#     'quant': 2982045,
#     'amonut': 38986,
#     'marketSum': 3490},
#    {'itemcode': '401470',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-메타버스액티브',
#     'nowVal': 13435,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.19,
#     'nav': 13467.0,
#     'threeMonthEarnRate': None,
#     'quant': 6225809,
#     'amonut': 82715,
#     'marketSum': 3439},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥 150',
#     'nowVal': 14910,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.44,
#     'nav': 15094.0,
#     'threeMonthEarnRate': 2.983,
#     'quant': 2778479,
#     'amonut': 41243,
#     'marketSum': 3429},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 12920,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.58,
#     'nav': 12957.0,
#     'threeMonthEarnRate': 0.1155,
#     'quant': 6167,
#     'amonut': 79,
#     'marketSum': 3346},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 14890,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.3,
#     'nav': None,
#     'threeMonthEarnRate': 9.3658,
#     'quant': 163988,
#     'amonut': 2443,
#     'marketSum': 3320},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 11440,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.52,
#     'nav': 11450.0,
#     'threeMonthEarnRate': -0.5191,
#     'quant': 75040,
#     'amonut': 860,
#     'marketSum': 3318},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 8350,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.18,
#     'nav': None,
#     'threeMonthEarnRate': 5.6854,
#     'quant': 396846,
#     'amonut': 3310,
#     'marketSum': 3307},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 15870,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -0.91,
#     'nav': 15923.0,
#     'threeMonthEarnRate': -1.4765,
#     'quant': 84,
#     'amonut': 1,
#     'marketSum': 3095},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 54820,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.26,
#     'nav': None,
#     'threeMonthEarnRate': 5.0024,
#     'quant': 12151,
#     'amonut': 666,
#     'marketSum': 2604},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50495,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.04,
#     'nav': 50499.0,
#     'threeMonthEarnRate': 0.2082,
#     'quant': 133837,
#     'amonut': 6759,
#     'marketSum': 2577},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 19370,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -0.79,
#     'nav': None,
#     'threeMonthEarnRate': 2.3591,
#     'quant': 25902,
#     'amonut': 501,
#     'marketSum': 2557},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 100155,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100145.0,
#     'threeMonthEarnRate': 0.1199,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 2554},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 102230,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102226.0,
#     'threeMonthEarnRate': 0.0783,
#     'quant': 149922,
#     'amonut': 15323,
#     'marketSum': 2535},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 117875,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.01,
#     'nav': 117899.0,
#     'threeMonthEarnRate': -3.7162,
#     'quant': 5022,
#     'amonut': 591,
#     'marketSum': 2452},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 36850,
#     'risefall': '5',
#     'changeVal': -605,
#     'changeRate': -1.62,
#     'nav': 36866.0,
#     'threeMonthEarnRate': 7.7066,
#     'quant': 249149,
#     'amonut': 9205,
#     'marketSum': 2451},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 13470,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.55,
#     'nav': 13483.0,
#     'threeMonthEarnRate': -1.9899,
#     'quant': 159479,
#     'amonut': 2147,
#     'marketSum': 2445},
#    {'itemcode': '108450',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 삼성그룹섹터가중',
#     'nowVal': 16320,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -1.03,
#     'nav': 16368.0,
#     'threeMonthEarnRate': -4.3226,
#     'quant': 174,
#     'amonut': 2,
#     'marketSum': 2415},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 12120,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.5,
#     'nav': None,
#     'threeMonthEarnRate': 4.5967,
#     'quant': 141625,
#     'amonut': 1710,
#     'marketSum': 2351},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 23520,
#     'risefall': '2',
#     'changeVal': 385,
#     'changeRate': 1.66,
#     'nav': None,
#     'threeMonthEarnRate': 7.4796,
#     'quant': 95082,
#     'amonut': 2224,
#     'marketSum': 2305},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12135,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.61,
#     'nav': None,
#     'threeMonthEarnRate': 0.909,
#     'quant': 116171,
#     'amonut': 1407,
#     'marketSum': 2245},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 32085,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -0.68,
#     'nav': None,
#     'threeMonthEarnRate': 4.9545,
#     'quant': 887,
#     'amonut': 28,
#     'marketSum': 2214},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 12490,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.32,
#     'nav': 12505.0,
#     'threeMonthEarnRate': 2.935,
#     'quant': 36630,
#     'amonut': 458,
#     'marketSum': 2125},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 22530,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.44,
#     'nav': 22539.0,
#     'threeMonthEarnRate': 3.1684,
#     'quant': 49714,
#     'amonut': 1117,
#     'marketSum': 2100},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 12750,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.27,
#     'nav': None,
#     'threeMonthEarnRate': 9.2735,
#     'quant': 445464,
#     'amonut': 5679,
#     'marketSum': 2066},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 12095,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.82,
#     'nav': None,
#     'threeMonthEarnRate': 17.1469,
#     'quant': 257500,
#     'amonut': 3119,
#     'marketSum': 2037},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 47035,
#     'risefall': '5',
#     'changeVal': -300,
#     'changeRate': -0.63,
#     'nav': 47115.0,
#     'threeMonthEarnRate': -1.9777,
#     'quant': 85,
#     'amonut': 4,
#     'marketSum': 2023},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 10175,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': 1.1934,
#     'quant': 38032,
#     'amonut': 387,
#     'marketSum': 1940},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 12265,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': None,
#     'threeMonthEarnRate': 6.6579,
#     'quant': 187015,
#     'amonut': 2297,
#     'marketSum': 1938},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50210,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 50208.0,
#     'threeMonthEarnRate': 0.1395,
#     'quant': 2330,
#     'amonut': 116,
#     'marketSum': 1884},
#    {'itemcode': '390950',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기채권액티브',
#     'nowVal': 100265,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100257.0,
#     'threeMonthEarnRate': 0.1498,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 1859},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100580,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 100577.0,
#     'threeMonthEarnRate': 0.1742,
#     'quant': 530,
#     'amonut': 53,
#     'marketSum': 1840},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 13050,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': 13058.0,
#     'threeMonthEarnRate': 1.755,
#     'quant': 81258,
#     'amonut': 1065,
#     'marketSum': 1814},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 12280,
#     'risefall': '2',
#     'changeVal': 460,
#     'changeRate': 3.89,
#     'nav': None,
#     'threeMonthEarnRate': 22.4236,
#     'quant': 359946,
#     'amonut': 4395,
#     'marketSum': 1808},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 15940,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.89,
#     'nav': None,
#     'threeMonthEarnRate': 5.5867,
#     'quant': 16234,
#     'amonut': 258,
#     'marketSum': 1769},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 30105,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.36,
#     'nav': 30096.0,
#     'threeMonthEarnRate': -2.6736,
#     'quant': 115,
#     'amonut': 3,
#     'marketSum': 1701},
#    {'itemcode': '278240',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 16520,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.82,
#     'nav': 16503.0,
#     'threeMonthEarnRate': 7.337,
#     'quant': 12285,
#     'amonut': 200,
#     'marketSum': 1647},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 14435,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.31,
#     'nav': None,
#     'threeMonthEarnRate': 9.3242,
#     'quant': 93939,
#     'amonut': 1356,
#     'marketSum': 1617},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 14830,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.1,
#     'nav': 15029.0,
#     'threeMonthEarnRate': 3.6376,
#     'quant': 19937,
#     'amonut': 295,
#     'marketSum': 1596},
#    {'itemcode': '401170',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR iSelect메타버스',
#     'nowVal': 12535,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.44,
#     'nav': 12532.0,
#     'threeMonthEarnRate': None,
#     'quant': 914470,
#     'amonut': 11405,
#     'marketSum': 1572},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 15130,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.3,
#     'nav': 15311.0,
#     'threeMonthEarnRate': 3.11,
#     'quant': 11340,
#     'amonut': 171,
#     'marketSum': 1558},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 96785,
#     'risefall': '5',
#     'changeVal': -295,
#     'changeRate': -0.3,
#     'nav': 96789.0,
#     'threeMonthEarnRate': -10.4329,
#     'quant': 157,
#     'amonut': 15,
#     'marketSum': 1520},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 8360,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.24,
#     'nav': None,
#     'threeMonthEarnRate': 5.608,
#     'quant': 309437,
#     'amonut': 2584,
#     'marketSum': 1509},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 35920,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.24,
#     'nav': 36134.0,
#     'threeMonthEarnRate': -20.51,
#     'quant': 35289,
#     'amonut': 1273,
#     'marketSum': 1451},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 37800,
#     'risefall': '5',
#     'changeVal': -680,
#     'changeRate': -1.77,
#     'nav': 37893.0,
#     'threeMonthEarnRate': 7.8928,
#     'quant': 61043,
#     'amonut': 2308,
#     'marketSum': 1444},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 4815,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -1.83,
#     'nav': 4827.0,
#     'threeMonthEarnRate': -3.7292,
#     'quant': 1076633,
#     'amonut': 5205,
#     'marketSum': 1348},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 7955,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.81,
#     'nav': 7972.0,
#     'threeMonthEarnRate': -5.4246,
#     'quant': 8729,
#     'amonut': 69,
#     'marketSum': 1341},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 24215,
#     'risefall': '5',
#     'changeVal': -240,
#     'changeRate': -0.98,
#     'nav': 24215.0,
#     'threeMonthEarnRate': -2.0037,
#     'quant': 15694,
#     'amonut': 380,
#     'marketSum': 1332},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 22585,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.31,
#     'nav': None,
#     'threeMonthEarnRate': 5.0629,
#     'quant': 10760,
#     'amonut': 243,
#     'marketSum': 1310},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 2310,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.87,
#     'nav': 2314.0,
#     'threeMonthEarnRate': 2.2321,
#     'quant': 2513321,
#     'amonut': 5763,
#     'marketSum': 1310},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 17740,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -1.0,
#     'nav': 17741.0,
#     'threeMonthEarnRate': -4.6809,
#     'quant': 284966,
#     'amonut': 5116,
#     'marketSum': 1295},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 32590,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.32,
#     'nav': None,
#     'threeMonthEarnRate': 9.2747,
#     'quant': 7044,
#     'amonut': 229,
#     'marketSum': 1206},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 10840,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.74,
#     'nav': 10837.0,
#     'threeMonthEarnRate': 2.5999,
#     'quant': 302156,
#     'amonut': 3285,
#     'marketSum': 1203},
#    {'itemcode': '395750',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG가치주액티브',
#     'nowVal': 9390,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.69,
#     'nav': 9417.0,
#     'threeMonthEarnRate': 0.0,
#     'quant': 48,
#     'amonut': 0,
#     'marketSum': 1193},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 18275,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -0.84,
#     'nav': 18312.0,
#     'threeMonthEarnRate': -5.5115,
#     'quant': 113026,
#     'amonut': 2064,
#     'marketSum': 1170},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 부동산인프라고배당',
#     'nowVal': 6035,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.5,
#     'nav': 6042.0,
#     'threeMonthEarnRate': 6.2267,
#     'quant': 125780,
#     'amonut': 759,
#     'marketSum': 1165},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 10500,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.14,
#     'nav': 10508.0,
#     'threeMonthEarnRate': 1.1544,
#     'quant': 58622,
#     'amonut': 615,
#     'marketSum': 1152},
#    {'itemcode': '309230',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 18185,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.14,
#     'nav': None,
#     'threeMonthEarnRate': 1.7602,
#     'quant': 14980,
#     'amonut': 272,
#     'marketSum': 1146},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 102830,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 102827.0,
#     'threeMonthEarnRate': 0.1899,
#     'quant': 103,
#     'amonut': 10,
#     'marketSum': 1142},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 20390,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -0.68,
#     'nav': None,
#     'threeMonthEarnRate': 4.2926,
#     'quant': 51185,
#     'amonut': 1046,
#     'marketSum': 1121},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101285,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.01,
#     'nav': 101292.0,
#     'threeMonthEarnRate': 0.1136,
#     'quant': 115680,
#     'amonut': 11717,
#     'marketSum': 1097},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 57275,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.03,
#     'nav': 57290.0,
#     'threeMonthEarnRate': -1.4196,
#     'quant': 20758,
#     'amonut': 1188,
#     'marketSum': 1096},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 11465,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.13,
#     'nav': 11425.0,
#     'threeMonthEarnRate': -0.2607,
#     'quant': 35775,
#     'amonut': 409,
#     'marketSum': 1055},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 3065,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.66,
#     'nav': 3066.0,
#     'threeMonthEarnRate': 1.6694,
#     'quant': 146410,
#     'amonut': 448,
#     'marketSum': 1051},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 17515,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -0.96,
#     'nav': 17600.0,
#     'threeMonthEarnRate': -2.8297,
#     'quant': 44,
#     'amonut': 0,
#     'marketSum': 1051},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 15100,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.23,
#     'nav': 15088.0,
#     'threeMonthEarnRate': -2.9497,
#     'quant': 25,
#     'amonut': 0,
#     'marketSum': 1042},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 10435,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.0,
#     'nav': 10437.0,
#     'threeMonthEarnRate': 30.8504,
#     'quant': 775005,
#     'amonut': 8023,
#     'marketSum': 1027},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나CSI300',
#     'nowVal': 14640,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.31,
#     'nav': None,
#     'threeMonthEarnRate': 5.2688,
#     'quant': 15787,
#     'amonut': 231,
#     'marketSum': 1025},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 12175,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.12,
#     'nav': None,
#     'threeMonthEarnRate': 6.2472,
#     'quant': 73729,
#     'amonut': 898,
#     'marketSum': 998},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 36960,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.3,
#     'nav': None,
#     'threeMonthEarnRate': 9.169,
#     'quant': 4827,
#     'amonut': 178,
#     'marketSum': 998},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 4835,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -1.73,
#     'nav': None,
#     'threeMonthEarnRate': 3.2528,
#     'quant': 362362,
#     'amonut': 1752,
#     'marketSum': 967},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 8720,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.46,
#     'nav': 8733.0,
#     'threeMonthEarnRate': -20.6944,
#     'quant': 368628,
#     'amonut': 3226,
#     'marketSum': 959},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 17635,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.31,
#     'nav': 17637.0,
#     'threeMonthEarnRate': -5.8793,
#     'quant': 100063,
#     'amonut': 1759,
#     'marketSum': 924},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3435,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.44,
#     'nav': 3435.0,
#     'threeMonthEarnRate': -1.441,
#     'quant': 130708,
#     'amonut': 449,
#     'marketSum': 907},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 20670,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.27,
#     'nav': None,
#     'threeMonthEarnRate': 7.8303,
#     'quant': 13053,
#     'amonut': 269,
#     'marketSum': 899},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 11080,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.82,
#     'nav': None,
#     'threeMonthEarnRate': -3.3422,
#     'quant': 31155,
#     'amonut': 342,
#     'marketSum': 895},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 10840,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.78,
#     'nav': 10872.0,
#     'threeMonthEarnRate': -12.0017,
#     'quant': 1296,
#     'amonut': 14,
#     'marketSum': 876},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 13895,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.54,
#     'nav': 13926.0,
#     'threeMonthEarnRate': 2.4944,
#     'quant': 8205,
#     'amonut': 115,
#     'marketSum': 875},
#    {'itemcode': '122260',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 통안채1년',
#     'nowVal': 101215,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.03,
#     'nav': 101237.0,
#     'threeMonthEarnRate': -0.0149,
#     'quant': 10925,
#     'amonut': 1105,
#     'marketSum': 870},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 14600,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.38,
#     'nav': None,
#     'threeMonthEarnRate': 3.0953,
#     'quant': 19631,
#     'amonut': 286,
#     'marketSum': 847},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 9330,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.43,
#     'nav': 9340.0,
#     'threeMonthEarnRate': 1.6967,
#     'quant': 7620,
#     'amonut': 70,
#     'marketSum': 835},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 12395,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.52,
#     'nav': 12433.0,
#     'threeMonthEarnRate': 2.4586,
#     'quant': 5526,
#     'amonut': 68,
#     'marketSum': 812},
#    {'itemcode': '136340',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중기우량회사채',
#     'nowVal': 103885,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.02,
#     'nav': 103886.0,
#     'threeMonthEarnRate': -1.3201,
#     'quant': 15,
#     'amonut': 1,
#     'marketSum': 810},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 21525,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.25,
#     'nav': None,
#     'threeMonthEarnRate': 6.253,
#     'quant': 2973,
#     'amonut': 64,
#     'marketSum': 796},
#    {'itemcode': '387270',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌BBIG액티브',
#     'nowVal': 12645,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.82,
#     'nav': None,
#     'threeMonthEarnRate': 8.3722,
#     'quant': 54489,
#     'amonut': 690,
#     'marketSum': 752},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 11990,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.08,
#     'nav': None,
#     'threeMonthEarnRate': 1.437,
#     'quant': 32423,
#     'amonut': 389,
#     'marketSum': 746},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 12360,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.31,
#     'nav': 12369.0,
#     'threeMonthEarnRate': 13.6999,
#     'quant': 521201,
#     'amonut': 6407,
#     'marketSum': 742},
#    {'itemcode': '387280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'nowVal': 12270,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.07,
#     'nav': 12249.0,
#     'threeMonthEarnRate': 15.3992,
#     'quant': 45381,
#     'amonut': 552,
#     'marketSum': 739},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 21580,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.47,
#     'nav': None,
#     'threeMonthEarnRate': 2.5787,
#     'quant': 19918,
#     'amonut': 430,
#     'marketSum': 738},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 30400,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.07,
#     'nav': 30420.0,
#     'threeMonthEarnRate': -2.9511,
#     'quant': 292,
#     'amonut': 8,
#     'marketSum': 730},
#    {'itemcode': '376410',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 탄소효율그린뉴딜',
#     'nowVal': 9645,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.05,
#     'nav': 9639.0,
#     'threeMonthEarnRate': -1.2788,
#     'quant': 41885,
#     'amonut': 404,
#     'marketSum': 723},
#    {'itemcode': '391600',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국친환경그린테마INDXX',
#     'nowVal': 11385,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.61,
#     'nav': None,
#     'threeMonthEarnRate': 18.7046,
#     'quant': 115066,
#     'amonut': 1310,
#     'marketSum': 706},
#    {'itemcode': '404540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX기후변화솔루션',
#     'nowVal': 10040,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.64,
#     'nav': 10059.0,
#     'threeMonthEarnRate': None,
#     'quant': 149136,
#     'amonut': 1492,
#     'marketSum': 703},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 11340,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.62,
#     'nav': 11372.0,
#     'threeMonthEarnRate': 12.1393,
#     'quant': 32077,
#     'amonut': 360,
#     'marketSum': 692},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 108910,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.07,
#     'nav': 109001.0,
#     'threeMonthEarnRate': -1.4468,
#     'quant': 3494,
#     'amonut': 380,
#     'marketSum': 686},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 12015,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': -1.5164,
#     'quant': 74512,
#     'amonut': 895,
#     'marketSum': 685},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4490,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.45,
#     'nav': 4496.0,
#     'threeMonthEarnRate': 1.5909,
#     'quant': 66222,
#     'amonut': 296,
#     'marketSum': 678},
#    {'itemcode': '396510',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#     'nowVal': 10760,
#     'risefall': '5',
#     'changeVal': -240,
#     'changeRate': -2.18,
#     'nav': None,
#     'threeMonthEarnRate': 9.7256,
#     'quant': 77297,
#     'amonut': 835,
#     'marketSum': 654},
#    {'itemcode': '365000',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX인터넷K-뉴딜',
#     'nowVal': 11630,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 11649.0,
#     'threeMonthEarnRate': -5.8277,
#     'quant': 37801,
#     'amonut': 439,
#     'marketSum': 645},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 101405,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 101339.0,
#     'threeMonthEarnRate': 1.7206,
#     'quant': 64,
#     'amonut': 6,
#     'marketSum': 635},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SOL KIS단기통안채',
#     'nowVal': 100530,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100520.0,
#     'threeMonthEarnRate': 0.1743,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 633},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 11090,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.94,
#     'nav': None,
#     'threeMonthEarnRate': 1.588,
#     'quant': 6036,
#     'amonut': 67,
#     'marketSum': 632},
#    {'itemcode': '368190',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#     'nowVal': 12195,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.37,
#     'nav': 12213.0,
#     'threeMonthEarnRate': -10.7222,
#     'quant': 5295,
#     'amonut': 64,
#     'marketSum': 628},
#    {'itemcode': '233160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 17090,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.71,
#     'nav': 17268.0,
#     'threeMonthEarnRate': 6.6289,
#     'quant': 110077,
#     'amonut': 1865,
#     'marketSum': 615},
#    {'itemcode': '354350',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#     'nowVal': 20465,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -1.11,
#     'nav': None,
#     'threeMonthEarnRate': 18.0884,
#     'quant': 27237,
#     'amonut': 557,
#     'marketSum': 604},
#    {'itemcode': '130680',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물Enhanced(H)',
#     'nowVal': 3705,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 3.78,
#     'nav': None,
#     'threeMonthEarnRate': 21.843,
#     'quant': 335004,
#     'amonut': 1234,
#     'marketSum': 598},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 3260,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.61,
#     'nav': 3260.0,
#     'threeMonthEarnRate': -1.9432,
#     'quant': 154348,
#     'amonut': 502,
#     'marketSum': 597},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 18935,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.58,
#     'nav': None,
#     'threeMonthEarnRate': 6.3859,
#     'quant': 32181,
#     'amonut': 608,
#     'marketSum': 596},
#    {'itemcode': '256750',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나심천ChiNext(합성)',
#     'nowVal': 15695,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.73,
#     'nav': None,
#     'threeMonthEarnRate': 9.7535,
#     'quant': 21573,
#     'amonut': 339,
#     'marketSum': 596},
#    {'itemcode': '385720',
#     'etfTabCode': 1,
#     'itemname': 'TIMEFOLIO Kstock액티브',
#     'nowVal': 10225,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.15,
#     'nav': 10278.0,
#     'threeMonthEarnRate': 0.9861,
#     'quant': 2640,
#     'amonut': 27,
#     'marketSum': 583},
#    {'itemcode': '315960',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 대형고배당10TR',
#     'nowVal': 16015,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.53,
#     'nav': 16035.0,
#     'threeMonthEarnRate': 4.2071,
#     'quant': 12410,
#     'amonut': 200,
#     'marketSum': 577},
#    {'itemcode': '395760',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG성장주액티브',
#     'nowVal': 9545,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.37,
#     'nav': 9590.0,
#     'threeMonthEarnRate': 0.4192,
#     'quant': 82,
#     'amonut': 0,
#     'marketSum': 573},
#    {'itemcode': '227830',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피',
#     'nowVal': 30785,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.21,
#     'nav': 30758.0,
#     'threeMonthEarnRate': -3.2006,
#     'quant': 141,
#     'amonut': 4,
#     'marketSum': 570},
#    {'itemcode': '266360',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 미디어&엔터테인먼트',
#     'nowVal': 26255,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.04,
#     'nav': 26265.0,
#     'threeMonthEarnRate': 3.0225,
#     'quant': 14735,
#     'amonut': 384,
#     'marketSum': 551},
#    {'itemcode': '102970',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 증권',
#     'nowVal': 7960,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.19,
#     'nav': 7979.0,
#     'threeMonthEarnRate': -0.7468,
#     'quant': 47934,
#     'amonut': 382,
#     'marketSum': 541},
#    {'itemcode': '388280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'nowVal': 9580,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -1.59,
#     'nav': 9603.0,
#     'threeMonthEarnRate': 3.6189,
#     'quant': 43280,
#     'amonut': 415,
#     'marketSum': 538},
#    {'itemcode': '117680',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 철강',
#     'nowVal': 8340,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.42,
#     'nav': 8347.0,
#     'threeMonthEarnRate': -7.7427,
#     'quant': 182386,
#     'amonut': 1532,
#     'marketSum': 537},
#    {'itemcode': '337160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200ESG',
#     'nowVal': 14045,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.81,
#     'nav': 14092.0,
#     'threeMonthEarnRate': -1.3585,
#     'quant': 644,
#     'amonut': 9,
#     'marketSum': 520},
#    {'itemcode': '371450',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#     'nowVal': 12030,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -2.04,
#     'nav': None,
#     'threeMonthEarnRate': 1.4876,
#     'quant': 68449,
#     'amonut': 823,
#     'marketSum': 515},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 51395,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.05,
#     'nav': 51405.0,
#     'threeMonthEarnRate': -2.6229,
#     'quant': 84,
#     'amonut': 4,
#     'marketSum': 514},
#    {'itemcode': '266370',
#     'etfTabCode': 2,
#     'itemname': 'KODEX IT',
#     'nowVal': 21270,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 21266.0,
#     'threeMonthEarnRate': 6.3765,
#     'quant': 18544,
#     'amonut': 396,
#     'marketSum': 510},
#    {'itemcode': '289260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER MSCI KOREA ESG리더스',
#     'nowVal': 11320,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.27,
#     'nav': 11318.0,
#     'threeMonthEarnRate': -2.7144,
#     'quant': 743,
#     'amonut': 8,
#     'marketSum': 509},
#    {'itemcode': '114460',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채3년',
#     'nowVal': 105055,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.05,
#     'nav': 105122.0,
#     'threeMonthEarnRate': -1.3885,
#     'quant': 105,
#     'amonut': 11,
#     'marketSum': 504},
#    {'itemcode': '404260',
#     'etfTabCode': 2,
#     'itemname': 'KODEX KRX기후변화솔루션',
#     'nowVal': 9990,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.65,
#     'nav': 10018.0,
#     'threeMonthEarnRate': None,
#     'quant': 2392,
#     'amonut': 23,
#     'marketSum': 500},
#    {'itemcode': '336160',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 금융채액티브',
#     'nowVal': 101870,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 101863.0,
#     'threeMonthEarnRate': -1.2505,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 499},
#    {'itemcode': '256440',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 인도네시아MSCI(합성)',
# ...
#     'nowVal': 8270,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.73,
#     'nav': 8258.0,
#     'threeMonthEarnRate': 2.0509,
#     'quant': 201,
#     'amonut': 1,
#     'marketSum': 58},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 7130,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.83,
#     'nav': None,
#     'threeMonthEarnRate': 6.4396,
#     'quant': 2512,
#     'amonut': 17,
#     'marketSum': 57},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 6240,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.48,
#     'nav': None,
#     'threeMonthEarnRate': 6.2711,
#     'quant': 215,
#     'amonut': 1,
#     'marketSum': 56},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 6580,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.15,
#     'nav': 6573.0,
#     'threeMonthEarnRate': -5.5874,
#     'quant': 2036,
#     'amonut': 13,
#     'marketSum': 56},
#    {'itemcode': '105010',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 라틴35',
#     'nowVal': 3235,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 1.25,
#     'nav': None,
#     'threeMonthEarnRate': -10.0,
#     'quant': 39016,
#     'amonut': 125,
#     'marketSum': 55},
#    {'itemcode': '346000',
#     'etfTabCode': 6,
#     'itemname': 'HANARO KAP초장기국고채',
#     'nowVal': 44465,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -0.31,
#     'nav': 44581.0,
#     'threeMonthEarnRate': -6.1304,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 54},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 10845,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.46,
#     'nav': None,
#     'threeMonthEarnRate': -0.5023,
#     'quant': 65,
#     'amonut': 0,
#     'marketSum': 54},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 9750,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.41,
#     'nav': 9763.0,
#     'threeMonthEarnRate': -2.5101,
#     'quant': 885,
#     'amonut': 8,
#     'marketSum': 53},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 50530,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50521.0,
#     'threeMonthEarnRate': 1.7007,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 52},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 101120,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 101106.0,
#     'threeMonthEarnRate': 1.7508,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 11125,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.45,
#     'nav': 11130.0,
#     'threeMonthEarnRate': -2.4018,
#     'quant': 8,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 11070,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.36,
#     'nav': None,
#     'threeMonthEarnRate': -1.2534,
#     'quant': 24,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '371870',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 차이나항셍테크',
#     'nowVal': 8235,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': 5.1052,
#     'quant': 1952,
#     'amonut': 16,
#     'marketSum': 49},
#    {'itemcode': '261270',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스',
#     'nowVal': 9630,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 9640.0,
#     'threeMonthEarnRate': -1.1801,
#     'quant': 5246,
#     'amonut': 50,
#     'marketSum': 49},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 98130,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.13,
#     'nav': 97920.0,
#     'threeMonthEarnRate': 4.6156,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 49},
#    {'itemcode': '253280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 헬스케어',
#     'nowVal': 13785,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.25,
#     'nav': 13857.0,
#     'threeMonthEarnRate': -20.6887,
#     'quant': 8239,
#     'amonut': 114,
#     'marketSum': 48},
#    {'itemcode': '275750',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4370,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.46,
#     'nav': 4380.0,
#     'threeMonthEarnRate': -5.6929,
#     'quant': 9673,
#     'amonut': 42,
#     'marketSum': 48},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 54130,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.07,
#     'nav': 54153.0,
#     'threeMonthEarnRate': -3.8602,
#     'quant': 292,
#     'amonut': 15,
#     'marketSum': 47},
#    {'itemcode': '227550',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 산업재',
#     'nowVal': 5960,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.5,
#     'nav': 5969.0,
#     'threeMonthEarnRate': -13.5643,
#     'quant': 86,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'nowVal': 15480,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.26,
#     'nav': 15475.0,
#     'threeMonthEarnRate': -1.9893,
#     'quant': 21,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 4705,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.21,
#     'nav': 4710.0,
#     'threeMonthEarnRate': 0.8556,
#     'quant': 8588,
#     'amonut': 40,
#     'marketSum': 46},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5250,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.57,
#     'nav': 5249.0,
#     'threeMonthEarnRate': 1.3592,
#     'quant': 165,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 11020,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.59,
#     'nav': 11010.0,
#     'threeMonthEarnRate': -5.3778,
#     'quant': 55,
#     'amonut': 0,
#     'marketSum': 44},
#    {'itemcode': '147970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 모멘텀',
#     'nowVal': 24255,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -0.82,
#     'nav': 24540.0,
#     'threeMonthEarnRate': 1.5573,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 44},
#    {'itemcode': '334690',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물(H)',
#     'nowVal': 10885,
#     'risefall': '5',
#     'changeVal': -500,
#     'changeRate': -4.39,
#     'nav': None,
#     'threeMonthEarnRate': -14.0106,
#     'quant': 40455,
#     'amonut': 437,
#     'marketSum': 44},
#    {'itemcode': '280940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 7210,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.7,
#     'nav': None,
#     'threeMonthEarnRate': -1.7833,
#     'quant': 2376,
#     'amonut': 17,
#     'marketSum': 43},
#    {'itemcode': '217770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 5070,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -3.7,
#     'nav': None,
#     'threeMonthEarnRate': -19.557,
#     'quant': 32717,
#     'amonut': 166,
#     'marketSum': 43},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 10105,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -1.13,
#     'nav': 10124.0,
#     'threeMonthEarnRate': -1.6362,
#     'quant': 28301,
#     'amonut': 285,
#     'marketSum': 42},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 12400,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.28,
#     'nav': 12441.0,
#     'threeMonthEarnRate': 2.0214,
#     'quant': 1500,
#     'amonut': 18,
#     'marketSum': 42},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 48875,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.08,
#     'nav': 48822.0,
#     'threeMonthEarnRate': 4.0925,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 42},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 11055,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11134.0,
#     'threeMonthEarnRate': -20.0362,
#     'quant': 10391,
#     'amonut': 115,
#     'marketSum': 42},
#    {'itemcode': '342600',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년스티프너2X',
#     'nowVal': 51590,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51606.0,
#     'threeMonthEarnRate': -0.3381,
#     'quant': 15,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '342500',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년스티프너',
#     'nowVal': 51095,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.05,
#     'nav': 51120.0,
#     'threeMonthEarnRate': -0.0978,
#     'quant': 245,
#     'amonut': 12,
#     'marketSum': 41},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 11595,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.22,
#     'nav': 11585.0,
#     'threeMonthEarnRate': 1.3578,
#     'quant': 15,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 10080,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.05,
#     'nav': None,
#     'threeMonthEarnRate': 1.5609,
#     'quant': 351,
#     'amonut': 3,
#     'marketSum': 40},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 7550,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.26,
#     'nav': 7545.0,
#     'threeMonthEarnRate': -5.3159,
#     'quant': 6185,
#     'amonut': 47,
#     'marketSum': 40},
#    {'itemcode': '342610',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년플래트너',
#     'nowVal': 49980,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.12,
#     'nav': 50002.0,
#     'threeMonthEarnRate': 0.4012,
#     'quant': 16,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '267450',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 7950,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.32,
#     'nav': None,
#     'threeMonthEarnRate': 1.6025,
#     'quant': 696,
#     'amonut': 5,
#     'marketSum': 40},
#    {'itemcode': '302180',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물10년인버스',
#     'nowVal': 49595,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.16,
#     'nav': 49587.0,
#     'threeMonthEarnRate': 4.0012,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '342620',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#     'nowVal': 49370,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 49359.0,
#     'threeMonthEarnRate': 0.5809,
#     'quant': 11,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 10170,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.49,
#     'nav': 10170.0,
#     'threeMonthEarnRate': -7.8865,
#     'quant': 1402,
#     'amonut': 14,
#     'marketSum': 39},
#    {'itemcode': '267490',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'nowVal': 12590,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.87,
#     'nav': None,
#     'threeMonthEarnRate': -10.5949,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 9215,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.16,
#     'nav': 9212.0,
#     'threeMonthEarnRate': -2.2836,
#     'quant': 178,
#     'amonut': 1,
#     'marketSum': 37},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 20305,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.27,
#     'nav': 20278.0,
#     'threeMonthEarnRate': -4.1883,
#     'quant': 13361,
#     'amonut': 270,
#     'marketSum': 37},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 23885,
#     'risefall': '5',
#     'changeVal': -190,
#     'changeRate': -0.79,
#     'nav': 23989.0,
#     'threeMonthEarnRate': -1.8749,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '267500',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 6070,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.66,
#     'nav': None,
#     'threeMonthEarnRate': 3.5193,
#     'quant': 9312,
#     'amonut': 56,
#     'marketSum': 33},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 8980,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 9005.0,
#     'threeMonthEarnRate': 3.339,
#     'quant': 1306,
#     'amonut': 11,
#     'marketSum': 31},
#    {'itemcode': '302170',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물3년인버스',
#     'nowVal': 50585,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50594.0,
#     'threeMonthEarnRate': 1.6886,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 30},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스닥150',
#     'nowVal': 14905,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.47,
#     'nav': 15062.0,
#     'threeMonthEarnRate': 2.771,
#     'quant': 337,
#     'amonut': 5,
#     'marketSum': 30},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 14220,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.57,
#     'nav': 14110.0,
#     'threeMonthEarnRate': -0.106,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 28},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 12775,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.83,
#     'nav': 12782.0,
#     'threeMonthEarnRate': -3.3563,
#     'quant': 140,
#     'amonut': 1,
#     'marketSum': 26},
#    {'itemcode': '397420',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물5년추종',
#     'nowVal': 48875,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.02,
#     'nav': 48875.0,
#     'threeMonthEarnRate': None,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 8350,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -1.36,
#     'nav': 8359.0,
#     'threeMonthEarnRate': -5.6825,
#     'quant': 8206,
#     'amonut': 68,
#     'marketSum': 23},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 5775,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 4.34,
#     'nav': None,
#     'threeMonthEarnRate': 10.479,
#     'quant': 3453,
#     'amonut': 19,
#     'marketSum': 23},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 7755,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.51,
#     'nav': 7756.0,
#     'threeMonthEarnRate': -7.7515,
#     'quant': 201,
#     'amonut': 1,
#     'marketSum': 20},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 10685,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.11,
#     'nav': 10684.0,
#     'threeMonthEarnRate': -1.8174,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 15},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 10670,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.88,
#     'nav': 10692.0,
#     'threeMonthEarnRate': -12.975,
#     'quant': 44,
#     'amonut': 0,
#     'marketSum': 13}]}}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
# etfItemList
etf_itemlist = etf_json["result"]['etfItemList']

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
# df

df = pd.DataFrame(etf_itemlist)
df.head()
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   39425        5       -175
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   20100        5       -225
# 2   102110           1              TIGER 200   39445        5       -185
# 3   252670           3       KODEX 200선물인버스2X    2225        2         25
# 4   153130           6             KODEX 단기채권  102990        5         -5
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0       -0.44   39456.0             -2.0239    1850963   73236      53815
# 1       -1.11       NaN             15.8779    3216944   65122      30287
# 2       -0.47   39488.0             -1.9861     251033    9952      22188
# 3        1.14    2222.0              2.3255  128211523  282593      20759
# 4        0.00  102986.0              0.1263      34183    3520      19435

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   39425        5       -175
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   20100        5       -225
# 2   102110           1              TIGER 200   39445        5       -185
# 3   252670           3       KODEX 200선물인버스2X    2225        2         25
# 4   153130           6             KODEX 단기채권  102990        5         -5
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0       -0.44   39456.0             -2.0239    1850963   73236      53815
# 1       -1.11       NaN             15.8779    3216944   65122      30287
# 2       -0.47   39488.0             -1.9861     251033    9952      22188
# 3        1.14    2222.0              2.3255  128211523  282593      20759
# 4        0.00  102986.0              0.1263      34183    3520      19435

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode            itemname  nowVal risefall  changeVal  \
# 519   285020           2      KBSTAR 200철강소재    8350        5       -115
# 520   334700           5  KBSTAR 팔라듐선물인버스(H)    5775        2        240
# 521   287330           2     KBSTAR 200생활소비재    7755        5        -40
# 522   287310           2     KBSTAR 200경기소비재   10685        5       -120
# 523   287320           2       KBSTAR 200산업재   10670        5        -95
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 519       -1.36   8359.0             -5.6825   8206      68         23
# 520        4.34      NaN             10.4790   3453      19         23
# 521       -0.51   7756.0             -7.7515    201       1         20
# 522       -1.11  10684.0             -1.8174     12       0         15
# 523       -0.88  10692.0            -12.9750     44       0         13

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.

import datetime 

today = datetime.datetime.today()

today.strftime("%Y-%m-%d")
# Out:
# '2021-11-24'

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
# file_name

file_name = f"etf_{today}_raw.csv"

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name,index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name,dtype={"itemcode": object})
# Out:
#     itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0     069500           1              KODEX 200   39425         5       -175
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   20100         5       -225
# 2     102110           1              TIGER 200   39445         5       -185
# 3     252670           3       KODEX 200선물인버스2X    2225         2         25
# 4     153130           6             KODEX 단기채권  102990         5         -5
# ..       ...         ...                    ...     ...       ...        ...
# 519   285020           2         KBSTAR 200철강소재    8350         5       -115
# 520   334700           5     KBSTAR 팔라듐선물인버스(H)    5775         2        240
# 521   287330           2        KBSTAR 200생활소비재    7755         5        -40
# 522   287310           2        KBSTAR 200경기소비재   10685         5       -120
# 523   287320           2          KBSTAR 200산업재   10670         5        -95
#
#      changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0         -0.44   39456.0             -2.0239    1850963   73236      53815
# 1         -1.11       NaN             15.8779    3216944   65122      30287
# 2         -0.47   39488.0             -1.9861     251033    9952      22188
# 3          1.14    2222.0              2.3255  128211523  282593      20759
# 4          0.00  102986.0              0.1263      34183    3520      19435
# ..          ...       ...                 ...        ...     ...        ...
# 519       -1.36    8359.0             -5.6825       8206      68         23
# 520        4.34       NaN             10.4790       3453      19         23
# 521       -0.51    7756.0             -7.7515        201       1         20
# 522       -1.11   10684.0             -1.8174         12       0         15
# 523       -0.88   10692.0            -12.9750         44       0         13
#
# [524 rows x 12 columns]
