# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/5.1%20%EC%97%85%EC%A2%85%20%ED%85%8C%EB%A7%88%EC%A3%BC%20%EC%88%98%EC%A7%91-input.ipynb)
#
# ## 업종/테마 미션
#
# * 팀장님이 우리 회사와 유사한 업종과 테마로 사업을 하고 있는 종목을 수집해서 분석해 달라는 미션을 주셨습니다.
# * 코스피에서 해당 업종 혹은 테마의 시가총액이 가장 많은 종목을 찾아주세요.
# * 해당 업종/테마의 거래량이 가장 많은 종목을 찾아주세요.
# * 최근 52주 최고가에서 현재가 기준으로 가장 손실이 크게 난 종목은 어떤 종목일까요?
# * 거래대금이 20위 안에 있는 코스피 종목 중에 "PER"가 가장 낮은 종목은 무엇일까요?
#
#
# ## 업종/테마주 수집
#
# 전체 실습을 하고 아래의 URL로 URL만 변경하게 되면 원하는 업종과 테마를 수집할 수 있습니다.
#
# * 2차 전지 : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=64
# * 제약 업종 : https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=261
# * 코로나19(덱사메타손) : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=442
# * 제약업체 : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=172
# * 바이오시밀러(복제 바이오의약품) : https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=241

# %%
# 라이브러리 로드 : pandas, matplotlib.pyplot
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux
        # colab에서는 runtime을 <꼭> 재시작 해야합니다.
        # 런타임을 재시작 하지 않고 폰트 설치를 하면 기본 설정 폰트가 로드되어 한글이 깨집니다.
        # !apt-get update -qq
        # !apt-get install fonts-nanum -qq  > /dev/null

        import matplotlib.font_manager as fm

        fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
        font = fm.FontProperties(fname=fontpath, size=9)
        fm._rebuild()
        font_family = "NanumBarunGothic"
    return font_family

# %%
font_family = get_font_family()

# %%
# 사용가능한 폰트 스타일
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# 그래프 스타일 설정
plt.style.use("seaborn")

# 폰트설정
plt.rc("font", family=font_family)

# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)

# # 그래프에 retina display 적용
# from IPython.display import set_matplotlib_formats
# set_matplotlib_formats("retina")

# %%
# 한글폰트가 제대로 동작하는지 확인하기
pd.Series([1, 3, 5, -7, 9]).plot(title="한글")
# Out:
# <AxesSubplot:title={'center':'한글'}>

# %% [markdown]
# ### 제약업종 수집하기
# * https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=261

# %%
# 수집할 업종/테마주소
url = "https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=261"
# 2차전지
# url = "https://finance.naver.com/sise/sise_group_detail.nhn?type=theme&no=64"

# 크래프톤 관련주 
# url = "https://finance.naver.com/sise/sise_group_detail.naver?type=theme&no=486"

# %%
# read_html을 통해 해당 업종/테마를 수집합니다.
# table
table = pd.read_html(url, encoding="cp949")
len(table)
table[2]
# Out:
#           종목명       현재가      전일비      등락률      매수호가      매도호가        거래량  \
# 0         NaN       NaN      NaN      NaN       NaN       NaN        NaN
# 1      에스티팜 *  113900.0  14800.0  +14.93%  114000.0  114100.0  1015737.0
# 2     진바이오텍 *    5800.0    480.0   +9.02%    5740.0    5750.0  3821421.0
# 3    차백신연구소 *   11200.0    800.0   +7.69%   11050.0   11100.0  3525525.0
# 4      에이비온 *   12700.0    750.0   +6.28%   12450.0   12500.0   213714.0
# ..        ...       ...      ...      ...       ...       ...        ...
# 150  씨티씨바이오 *    7490.0    740.0   -8.99%    7370.0    7390.0   390673.0
# 151      신풍제약   32150.0   4300.0  -11.80%   31800.0   31850.0  9359181.0
# 152     신풍제약우   40600.0   6200.0  -13.25%   40300.0   40450.0   241089.0
# 153       NaN       NaN      NaN      NaN       NaN       NaN        NaN
# 154       NaN       NaN      NaN      NaN       NaN       NaN        NaN
#
#          거래대금       전일거래량  토론실  Unnamed: 10  Unnamed: 11
# 0         NaN         NaN  NaN          NaN          NaN
# 1    111141.0    429312.0  NaN          NaN          NaN
# 2     22445.0   4653164.0  NaN          NaN          NaN
# 3     39313.0   1813404.0  NaN          NaN          NaN
# 4      2737.0     38564.0  NaN          NaN          NaN
# ..        ...         ...  ...          ...          ...
# 150    2981.0    136664.0  NaN          NaN          NaN
# 151  300126.0  11653906.0  NaN          NaN          NaN
# 152    9720.0    413262.0  NaN          NaN          NaN
# 153       NaN         NaN  NaN          NaN          NaN
# 154       NaN         NaN  NaN          NaN          NaN
#
# [155 rows x 12 columns]

# %%
# 데이터들은 table[2]에 전부 있고
# dropna를 통해 결측치를 제거합니다.
# how='all' 이면 전부 결측치일시 row나 column을 제거합니다.
# raw
# 3개의 row, 3개의 column이 제거되었습니다.

raw = table[2]
print(raw.shape)
raw = raw.dropna(how="all").dropna(axis=1,how = "all")
raw.shape
# Out:
# (155, 12)
# (152, 9)

# %% [markdown]
# ## 파생변수 만들기

# %%
# datetime을 이용하여 조회한 날짜를 DataFrame에 기록합니다.

# today

import datetime

# today = datetime.datetime.today("%Y-%m-%d")

today = datetime.datetime.today().strftime("%Y-%m-%d")
today
# Out:
# '2021-11-25'

# %%
# 일자별로 데이터가 다르니 조회일자를 추가해 줍니다.
# raw["조회일자"]

raw["조회일자"] = today

# %%
# 조회일자가 추가되었는지 확인해 봅니다.
raw
# Out:
#             종목명       현재가      전일비      등락률      매수호가      매도호가        거래량  \
# 1        에스티팜 *  113900.0  14800.0  +14.93%  114000.0  114100.0  1015737.0
# 2       진바이오텍 *    5800.0    480.0   +9.02%    5740.0    5750.0  3821421.0
# 3      차백신연구소 *   11200.0    800.0   +7.69%   11050.0   11100.0  3525525.0
# 4        에이비온 *   12700.0    750.0   +6.28%   12450.0   12500.0   213714.0
# 5       HK이노엔 *   60700.0   3000.0   +5.20%   60700.0   60800.0   614938.0
# ..          ...       ...      ...      ...       ...       ...        ...
# 148     유유제약2우B   17150.0    850.0   -4.72%   17700.0   17800.0     2108.0
# 149  에스씨엠생명과학 *   15350.0    900.0   -5.54%   15300.0   15350.0    91062.0
# 150    씨티씨바이오 *    7490.0    740.0   -8.99%    7370.0    7390.0   390673.0
# 151        신풍제약   32150.0   4300.0  -11.80%   31800.0   31850.0  9359181.0
# 152       신풍제약우   40600.0   6200.0  -13.25%   40300.0   40450.0   241089.0
#
#          거래대금       전일거래량        조회일자
# 1    111141.0    429312.0  2021-11-25
# 2     22445.0   4653164.0  2021-11-25
# 3     39313.0   1813404.0  2021-11-25
# 4      2737.0     38564.0  2021-11-25
# 5     36799.0    457291.0  2021-11-25
# ..        ...         ...         ...
# 148      35.0       426.0  2021-11-25
# 149    1407.0     41000.0  2021-11-25
# 150    2981.0    136664.0  2021-11-25
# 151  300126.0  11653906.0  2021-11-25
# 152    9720.0    413262.0  2021-11-25
#
# [152 rows x 10 columns]

# %% [markdown]
# ## 거래량과 거래대금 시각화

# %%
# 종목명 대비 거래량을 bar chart로 그립니다.
# set_index를 해주면 plot시에 y axis label로 그려집니다.
# sort_values시의 기본값이 오름차순이기 때문에 
# DataFrame의 하위 30개를 가져와야 거래량 상위 30개의 종목을 시각화 합니다.
# temp

temp = raw[["종목명", "거래량"]].sort_values("거래량")

temp.set_index("종목명").plot.barh()
# Out:
# <AxesSubplot:ylabel='종목명'>

# %%
# 위와 동일한 방법으로 종목명 대비 거래대금의 bar chart를 시각화 합니다.
# temp
temp = raw[["종목명", "거래대금"]].set_index("종목명").sort_values("거래대금")

temp.plot.barh()
# Out:
# <AxesSubplot:ylabel='종목명'>

# %% [markdown]
# ## 종목코드 병합
# * 종목명을 통해 미리 수집해 두었던 krx 전체 상장 종목 목록을 가져오거나 수집해서 데이터를 병합합니다.

# %%
# 기존 종목명에는 * 표시가 있기 때문에 * 문자를 제거해서 "종목명_전처리"라는 새로운 컬럼에 담아줍니다.


raw["종목명_전처리"] = raw["종목명"].str.replace("*","")

raw["종목명_전처리"] = raw["종목명_전처리"].str.strip()

raw[["종목명", "종목명_전처리"]]
# Out:
# /var/folders/gk/575ywhys2fl6cy6yy62tjl8h0000gn/T/ipykernel_43404/3905677232.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   raw["종목명_전처리"] = raw["종목명"].str.replace("*","")
#             종목명   종목명_전처리
# 1        에스티팜 *      에스티팜
# 2       진바이오텍 *     진바이오텍
# 3      차백신연구소 *    차백신연구소
# 4        에이비온 *      에이비온
# 5       HK이노엔 *     HK이노엔
# ..          ...       ...
# 148     유유제약2우B   유유제약2우B
# 149  에스씨엠생명과학 *  에스씨엠생명과학
# 150    씨티씨바이오 *    씨티씨바이오
# 151        신풍제약      신풍제약
# 152       신풍제약우     신풍제약우
#
# [152 rows x 2 columns]

# %%
# raw 변수에 담긴 데이터프레임을 확인합니다.

# %%
# 저장해 두었던 전체거래소목록(krx.csv) 파일을 불러오거나 
# FinanceDataReader로 StockListing을 다시 받아서 df_krx 라는 변수에 담습니다.

df_krx = pd.read_csv("krx.csv")

df_krx
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S                  전자부품 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 6859  000547   KOSPI  흥국화재2우B                       NaN
# 6860  000545   KOSPI    흥국화재우                       NaN
# 6861  003280   KOSPI     흥아해운                    해상 운송업
# 6862  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 6863  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 6859                             NaN         NaN         NaN
# 6860                             NaN         NaN         NaN
# 6861                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 6862                       설계 및 감리용역  2000-02-03         12월
# 6863  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 6859                   NaN                            NaN    NaN
# 6860                   NaN                            NaN    NaN
# 6861                   이환구         http://www.heung-a.com  서울특별시
# 6862  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 6863                   김주환          http://www.hims.co.kr  인천광역시
#
# [6864 rows x 10 columns]

# %% [markdown]
# ### merge 를 통한 종목코드 만들기
# * concat과 merge의 차이
#     * concat :
#         * axis=0 행을 기준으로 위아래로 같은 컬럼끼리 값을 이어 붙여 새로운 행을 만듦
#         * axis=1 컬럼을 기준으로 인덱스가 같은 값을 옆으로 붙여 새로운 컬럼을 만듦
#     * merge :
#         * index 혹은 특정 컬럼 값을 기준으로 두 개의 데이터프레임을 연결
# <img src="https://pandas.pydata.org/docs/_images/merging_concat_axis1_join_axes.png">

# %%
# "Symbol", "Name" 만 사용하기 위해 따로 df_item_code_name 변수로 가져옵니다.
# 연결할 key 값으로 사용할 컬럼명을 같게 만들어 주면 전처리가 줄어듭니다.
# Symbol => "종목코드", Name => "종목명_전처리" 로 만들어주면 
# "종목명_전처리" 를 키값으로 합쳤을 때 전처리가 줄어듭니다.


df_item_code_name = df_krx[["Symbol", "Name"]]
df_item_code_name.columns = ["종목코드", "종목명_전처리"]
df_item_code_name.head()
# Out:
#      종목코드 종목명_전처리
# 0  060310      3S
# 1  095570  AJ네트웍스
# 2  006840   AK홀딩스
# 3  054620  APS홀딩스
# 4  265520   AP시스템

# %%
# 종목갯수를 확인하기 위해 df의 행과 열의 수를 출력합니다.
raw.shape
# Out:
# (8, 12)

# %%
# 종목코드를 만들어주기 위해 종목명_전처리 컬럼을 기준으로 df_item_code_name 데이터프레임과 병합합니다.
# merge- 합집합 개념이라서 중복되는 필드 있다면 자동으로 하나만 합쳐짐 - outter join
# left - left join 
# right - right join 
# df

df = raw.merge(df_item_code_name)
df.shape
# Out:
# (152, 12)

# %%
# 병합이 잘 되었는지 확인합니다.

# %% [markdown]
# ## 종목상세정보 수집
#
# '종목코드', '시가총액', '시가총액순위', '상장주식수', '액면가l매매단위', '외국인한도주식수(A)',
# '외국인보유주식수(B)', '외국인소진율(B/A)', '투자의견l목표주가', '52주최고l최저',
# '추정PERlEPS', '동일업종 PER', '동일업종 등락률', '배당수익률'

# %%
# 전체 종목을 수집하기 전에 일부 종목을 먼저 수집합니다.
item_code = "068270"
item_name = "셀트리온"

# %%
# 종목상세정보를 위한 url을 확보합니다.
# item_code에는 종목코드 수집시에 마지막에 수집된 데이터가 남아있습니다.
item_url =f"https://finance.naver.com/item/main.naver?code={item_code}"

# %%
# read_html을 이용해 데이터를 수집합니다.
tables = pd.read_html(item_url, encoding="cp949")

# %%
# 제대로 수집이 되었는지 확인합니다.
tables[3].iloc[:,[0,-1]]
# Out:
#        주요재무정보   최근 분기 실적
#        주요재무정보 2021.12(E)
#        주요재무정보     IFRS연결
# 0         매출액    5844.00
# 1        영업이익    2162.00
# 2       당기순이익    1659.00
# 3       영업이익률      37.00
# 4        순이익률      28.38
# 5   ROE(지배주주)        NaN
# 6        부채비율        NaN
# 7        당좌비율        NaN
# 8         유보율        NaN
# 9      EPS(원)    1213.00
# 10     PER(배)     174.01
# 11     BPS(원)   28987.00
# 12     PBR(배)       7.28
# 13   주당배당금(원)        NaN
# 14   시가배당률(%)        NaN
# 15    배당성향(%)        NaN

# %%
# tables의 원소값을 확인하여 원하는 데이터가 어디에 있는지 확인합니다.

tables[5]
#  0 1로만 필드가 구성된 자료들은 concat으로 행별로 합쳐주는 과정거치면 좋음 

pd.concat([tables[6],tables[7],tables[8],tables[9]]).set_index(0).T
# Out:
# 0 외국인한도주식수(A) 외국인보유주식수(B) 외국인소진율(B/A)           투자의견l목표주가  \
# 1   137947128    27787554      20.14%  4.00매수  l  289,727
#
# 0             52주최고l최저   PERlEPS(2021.09)          추정PERlEPS  \
# 1  396,239  l  193,500  52.41배  l  4,007원  46.00배  l  4,517원
#
# 0  PBRlBPS (2021.09) 배당수익률 동일업종 PER 동일업종 등락률
# 1  7.52배  l  27,914원   NaN   86.54배   +0.11%

# %% [markdown]
# ## 컬럼명과 값 형태로 되어 있는 테이블만 사용

# %%
# 수집한 정보를 item_info에 list 형태로 관리합니다.
item_info = []
item_info
# Out:
# []

# %%
# 초기화 

item_info = []
# 가장 최근의 주요재무정보를 가져와서 item_info 라는 변수에 담습니다.


finance_info = tables[3].iloc[:,[0,-1]]


# 위에 concat에 같이 합치기 위해서 인덱스 통일 
finance_info.columns = [0,1]
# finance_info
item_info.append(finance_info)


item_info
# Out:
# [            0         1
#  0         매출액   5844.00
#  1        영업이익   2162.00
#  2       당기순이익   1659.00
#  3       영업이익률     37.00
#  4        순이익률     28.38
#  5   ROE(지배주주)       NaN
#  6        부채비율       NaN
#  7        당좌비율       NaN
#  8         유보율       NaN
#  9      EPS(원)   1213.00
#  10     PER(배)    174.01
#  11     BPS(원)  28987.00
#  12     PBR(배)      7.28
#  13   주당배당금(원)       NaN
#  14   시가배당률(%)       NaN
#  15    배당성향(%)       NaN]

# %%
# tables을 반복문으로 돌며 컬럼의 수가 2인 테이블만 따로 추출해 
# 위에서 만든 item_info 에 리스트 형태로 추가합니다.

for t in tables:
    print(t.shape)
    if t.shape[1] == 2: 
        item_info.append(t)
# Out:
# (2, 3)
# (7, 4)
# (8, 5)
# (16, 11)
# (14, 6)
# (4, 2)
# (3, 2)
# (2, 2)
# (4, 2)
# (2, 2)
# (24, 3)
# (11, 3)
# (11, 3)

# %%
# 위에서 만든 리스트의 값을 확인합니다.
item_info
# Out:
# [            0         1
#  0         매출액   5844.00
#  1        영업이익   2162.00
#  2       당기순이익   1659.00
#  3       영업이익률     37.00
#  4        순이익률     28.38
#  5   ROE(지배주주)       NaN
#  6        부채비율       NaN
#  7        당좌비율       NaN
#  8         유보율       NaN
#  9      EPS(원)   1213.00
#  10     PER(배)    174.01
#  11     BPS(원)  28987.00
#  12     PBR(배)      7.28
#  13   주당배당금(원)       NaN
#  14   시가배당률(%)       NaN
#  15    배당성향(%)       NaN,
#            0               1
#  0      시가총액  28조  9,689  억원
#  1    시가총액순위         코스피 12위
#  2     상장주식수       137947128
#  3  액면가l매매단위   1,000원  l  1주,
#               0          1
#  0  외국인한도주식수(A)  137947128
#  1  외국인보유주식수(B)   27787554
#  2  외국인소진율(B/A)     20.14%,
#             0                    1
#  0  투자의견l목표주가   4.00매수  l  289,727
#  1   52주최고l최저  396,239  l  193,500,
#                     0                  1
#  0   PERlEPS(2021.09)  52.41배  l  4,007원
#  1          추정PERlEPS  46.00배  l  4,517원
#  2  PBRlBPS (2021.09)  7.52배  l  27,914원
#  3              배당수익률                NaN,
#            0       1
#  0  동일업종 PER  86.54배
#  1  동일업종 등락률  +0.11%]

# %% [markdown]
# ## concat을 통해 데이터를 병합
#
# * concat과 merge의 차이
#     * concat :
#         * axis=0 행을 기준으로 위아래로 같은 컬럼끼리 값을 이어 붙여 새로운 행을 만듦
#         * axis=1 컬럼을 기준으로 인덱스가 같은 값을 옆으로 붙여 새로운 컬럼을 만듦
#     * merge :
#         * index 혹은 특정 컬럼 값을 기준으로 두 개의 데이터프레임을 연결
#
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/merging_concat_keys.png">

# %%
# item_info[0] 의 컬럼명을 봅니다. 같은 컬럼이 아니면 행끼리 합칠 수 없습니다.
item_info[0]
item_info[1]
item_info[2]
# Out:
#              0          1
# 0  외국인한도주식수(A)  137947128
# 1  외국인보유주식수(B)   27787554
# 2  외국인소진율(B/A)     20.14%

# %%
# concat을 이용하여 item_info를 하나의 DataFrame으로 만듭니다.
df_item = pd.concat(item_info).set_index(0)

# %% [markdown]
# ## transpose를 통해 행과 열의 위치를 변경

# %%
# transpose는 .transpose() 혹은  .T 로 사용해 보실 수 있습니다.
df_item.T
# Out:
# 0     매출액    영업이익   당기순이익 영업이익률   순이익률 ROE(지배주주) 부채비율 당좌비율  유보율  EPS(원)  ...  \
# 1  5844.0  2162.0  1659.0  37.0  28.38       NaN  NaN  NaN  NaN  1213.0  ...
#
# 0 외국인보유주식수(B) 외국인소진율(B/A)           투자의견l목표주가             52주최고l최저  \
# 1    27787554      20.14%  4.00매수  l  289,727  396,239  l  193,500
#
# 0   PERlEPS(2021.09)          추정PERlEPS  PBRlBPS (2021.09) 배당수익률 동일업종 PER  \
# 1  52.41배  l  4,007원  46.00배  l  4,517원  7.52배  l  27,914원   NaN   86.54배
#
# 0 동일업종 등락률
# 1   +0.11%
#
# [1 rows x 31 columns]

# %% [markdown]
# ## 개별 주가 정보를 수집하는 함수를 생성

# %%
# 위에서 한 종목코드에 대해 개별 주가 정보를 얻는 방법을 확인하였으니,
# 같은 방법으로 모든 종목코드의 주가 정보를 추출합니다.
# 무리한 네트워크 요청은 서버에 부담을 줍니다. 
# sleep을 사용해서 서버에 무리한 요청을 하지 않습니다.
import time

def get_item_info(item_code):
    
    # url 읽어서 자료 수집하기 
    item_url = f"https://finance.naver.com/item/main.nhn?code={item_code}"
    tables = pd.read_html(item_url, encoding="cp949")
    
    # 열이 0,1로 구성되는 자료 합치기 
    item_info = []
    ## 재무정보 
    finance_info = tables[3].iloc[:, [0, -1]]
    finance_info.columns = [0, 1]
    item_info.append(finance_info)
    
    ## 전체 데이터 중에 0,1인 정보들을 한 리스트에 넣기 
    for t in tables:
        if t.shape[1] == 2:
            item_info.append(t)
    ## 리스트의 요소들을 하나의 df로 연결         
    df_item = pd.concat(item_info)
    ## col name을 위해 set_index하고 transpose 
    df_item = df_item.set_index(0).T
    ## ddos 방지 
    time.sleep(0.1)
    return df_item

# %%
# 데이터프레임 형태로 종목정보를 수집해 왔습니다.
# 다른 종목도 아래와 같은 형태로 모아서 concat 으로 연결해 준다면 
# 종목끼리 정보를 비교해 볼 수 있을것 같습니다.

item_code = "068270"

get_item_info(item_code)
# Out:
# 0     매출액    영업이익   당기순이익 영업이익률   순이익률 ROE(지배주주) 부채비율 당좌비율  유보율  EPS(원)  ...  \
# 1  5844.0  2162.0  1659.0  37.0  28.38       NaN  NaN  NaN  NaN  1213.0  ...
#
# 0 외국인보유주식수(B) 외국인소진율(B/A)           투자의견l목표주가             52주최고l최저  \
# 1    27787554      20.14%  4.00매수  l  289,727  396,239  l  193,500
#
# 0   PERlEPS(2021.09)          추정PERlEPS  PBRlBPS (2021.09) 배당수익률 동일업종 PER  \
# 1  52.28배  l  4,007원  46.00배  l  4,517원  7.51배  l  27,914원   NaN   86.54배
#
# 0 동일업종 등락률
# 1   +0.06%
#
# [1 rows x 31 columns]

# %% [markdown]
# ## tqdm은?
# * 오래 걸리는 작업의 진행 상태를 표시합니다.
# * https://tqdm.github.io/

# %%
# tqdm은 total quality data management의 약자입니다.
# tqdm.auto 에서 tqdm을 불러옵니다.
from tqdm.auto import tqdm
tqdm.pandas()

# %%
# DataFrame의 종목코드 column에 있는 종목코드들값을 get_item_info 함수에 적용되어
# result에 series형태로 저장됩니다.
# result
result = df["종목코드"].progress_apply(get_item_info)
# Out:
#   0%|          | 0/152 [00:00<?, ?it/s]

# %%
# 필드명만 잔뜩?
result

# 각 값을 인덱싱해보면 잘 나온다 
result[10]

# series 
type(result)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## concat 을 통한 데이터 프레임 합치기
# * 수집한 종목마다의 정보를 하나의 데이터프레임으로 만듭니다.

# %%
# result를 list로 만들고 concat을 통해 DataFrame으로 만듭니다.
# concat으로 데이터프레임을 합쳐줄때는 리스트 형태로 각 데이터프레임을 넣어주어야 합니다. -> tolist(0)
df_item_info = pd.concat(result.tolist())

# 합치려고 봤는데 종목코드가 없음

# df_item_info["종목코드"]


# 종목코드가 있는 krx데이터에서 자료를 가져와서 새로운 파생변수를 만들어준다

df_item_info["종목코드"] = df["종목코드"]

# 확인을 해보면 모두 동일한 코드 ... 인덱스가 같기 때문에! 
df_item_info["종목코드"]

# index 초기화
df_item_info = df_item_info.reset_index()


df_item_info["종목코드"] = df["종목코드"]
df_item_info["종목코드"]

# index라는 컬럼은 이제 필요가 없음
del df_item_info['index']
df_item_info
# Out:
# 0       매출액   영업이익 당기순이익 영업이익률 순이익률 ROE(지배주주) 부채비율 당좌비율  유보율 EPS(원)  ...  \
# 0       NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 1       NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 2       NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 3       NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 4    1758.0  158.0   NaN  8.99  NaN       NaN  NaN  NaN  NaN  317.0  ...
# ..      ...    ...   ...   ...  ...       ...  ...  ...  ...    ...  ...
# 147     NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 148     NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 149     NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 150     NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
# 151     NaN    NaN   NaN   NaN  NaN       NaN  NaN  NaN  NaN    NaN  ...
#
# 0   동일업종 등락률 PERlEPS(2021.09) PBRlBPS (2021.09) 배당수익률l2020.12  \
# 0     +0.10%              NaN               NaN           NaN
# 1     +0.11%    N/A  l  -448원  1.13배  l  5,113원         0.52%
# 2     +0.11%              NaN               NaN           NaN
# 3     +0.10%              NaN               NaN           NaN
# 4     +0.10%              NaN               NaN           NaN
# ..       ...              ...               ...           ...
# 147   +0.11%     N/A  l  -52원  2.58배  l  6,642원         0.64%
# 148   +0.11%              NaN               NaN           NaN
# 149   +0.11%    N/A  l  -404원  2.04배  l  3,671원           NaN
# 150   +0.11%              NaN               NaN         0.31%
# 151   +0.08%              NaN               NaN         0.28%
#
# 0   PERlEPS(2020.12) PBRlBPS (2020.12) PERlEPS(2021.08) PBRlBPS (2021.08)  \
# 0                NaN               NaN              NaN               NaN
# 1                NaN               NaN              NaN               NaN
# 2        N/A  l  N/A       N/A  l  N/A              NaN               NaN
# 3      N/A  l  -756원   N/A  l  -4,980원              NaN               NaN
# 4                NaN               NaN              NaN               NaN
# ..               ...               ...              ...               ...
# 147              NaN               NaN              NaN               NaN
# 148              NaN               NaN              NaN               NaN
# 149              NaN               NaN              NaN               NaN
# 150              NaN               NaN              NaN               NaN
# 151              NaN               NaN              NaN               NaN
#
# 0   배당수익률l2020.11    종목코드
# 0             NaN  237690
# 1             NaN  086060
# 2             NaN  261780
# 3             NaN  203400
# 4             NaN  195940
# ..            ...     ...
# 147           NaN  000227
# 148           NaN  298060
# 149           NaN  060590
# 150           NaN  019170
# 151           NaN  019175
#
# [152 rows x 40 columns]

# %%
# 합쳐줄 해당 종목/테마 데이터프레임을 봅니다.
df.shape
# Out:
# (152, 12)

# %% [markdown]
# ## merge 를 통한 데이터프레임 합치기
# * 업종/테마 목록과 개별 종목 정보를 수집한 데이터프레임을 합쳐줍니다.

# %%
# DateFrame df와 df_item_info를 공통되는 column을 통해 합칩니다.
# "종목코드" 컬럼이 두 데이터프레임에 있기 때문에 "종목코드" 컬럼을 기준으로 merge됩니다.
df_info = df.merge(df_item_info)

# %%
# shape의 column수를 통해 데이터(종목코드)가 합쳐 졌음을 알 수 있습니다.
# df, df_item_info, df_info 확인하기
df.shape, df_item_info.shape, df_info.shape
# Out:
# ((152, 12), (152, 40), (152, 51))

# %%
# 일부 데이터만 가져와서 확인합니다.
df_info.head()
# Out:
#         종목명       현재가      전일비      등락률      매수호가      매도호가        거래량  \
# 0    에스티팜 *  113900.0  14800.0  +14.93%  114000.0  114100.0  1015737.0
# 1   진바이오텍 *    5800.0    480.0   +9.02%    5740.0    5750.0  3821421.0
# 2  차백신연구소 *   11200.0    800.0   +7.69%   11050.0   11100.0  3525525.0
# 3    에이비온 *   12700.0    750.0   +6.28%   12450.0   12500.0   213714.0
# 4   HK이노엔 *   60700.0   3000.0   +5.20%   60700.0   60800.0   614938.0
#
#        거래대금      전일거래량        조회일자  ... 동일업종 PER 동일업종 등락률 PERlEPS(2021.09)  \
# 0  111141.0   429312.0  2021-11-25  ...   86.54배   +0.10%              NaN
# 1   22445.0  4653164.0  2021-11-25  ...   86.54배   +0.11%    N/A  l  -448원
# 2   39313.0  1813404.0  2021-11-25  ...   86.54배   +0.11%              NaN
# 3    2737.0    38564.0  2021-11-25  ...   86.54배   +0.10%              NaN
# 4   36799.0   457291.0  2021-11-25  ...   86.54배   +0.10%              NaN
#
#   PBRlBPS (2021.09) 배당수익률l2020.12 PERlEPS(2020.12) PBRlBPS (2020.12)  \
# 0               NaN           NaN              NaN               NaN
# 1  1.13배  l  5,113원         0.52%              NaN               NaN
# 2               NaN           NaN      N/A  l  N/A       N/A  l  N/A
# 3               NaN           NaN    N/A  l  -756원   N/A  l  -4,980원
# 4               NaN           NaN              NaN               NaN
#
#   PERlEPS(2021.08) PBRlBPS (2021.08) 배당수익률l2020.11
# 0              NaN               NaN           NaN
# 1              NaN               NaN           NaN
# 2              NaN               NaN           NaN
# 3              NaN               NaN           NaN
# 4              NaN               NaN           NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# ## 파일명 만들기

# %%
# 파일 이름을 url의 정보를 이용하여 만듭니다.
# 업종_no_번호_날짜.csv, 혹은 테마_no_번호.csv 형태로 만듭니다.
url = "https://finance.naver.com/sise/sise_group_detail.nhn?type=upjong&no=261"
# upjong으로 구분됌 


file_name_1 = url.split("=")[1].replace("&","_")
file_name_2 = url.split("=")[2]

file_name = f"{file_name_1}_{file_name_2}_{today}.csv"
file_name
# Out:
# 'upjong_no_261_2021-11-25.csv'

# %%
# csv 파일로 저장합니다.
df_info.to_csv(file_name,index=False)

# %%
# 제대로 저장되었는지 확인합니다.
pd.read_csv('upjong_no_261_2021-11-25.csv')
# Out:
#             종목명       현재가      전일비      등락률      매수호가      매도호가        거래량  \
# 0        에스티팜 *  113900.0  14800.0  +14.93%  114000.0  114100.0  1015737.0
# 1       진바이오텍 *    5800.0    480.0   +9.02%    5740.0    5750.0  3821421.0
# 2      차백신연구소 *   11200.0    800.0   +7.69%   11050.0   11100.0  3525525.0
# 3        에이비온 *   12700.0    750.0   +6.28%   12450.0   12500.0   213714.0
# 4       HK이노엔 *   60700.0   3000.0   +5.20%   60700.0   60800.0   614938.0
# ..          ...       ...      ...      ...       ...       ...        ...
# 147     유유제약2우B   17150.0    850.0   -4.72%   17700.0   17800.0     2108.0
# 148  에스씨엠생명과학 *   15350.0    900.0   -5.54%   15300.0   15350.0    91062.0
# 149    씨티씨바이오 *    7490.0    740.0   -8.99%    7370.0    7390.0   390673.0
# 150        신풍제약   32150.0   4300.0  -11.80%   31800.0   31850.0  9359181.0
# 151       신풍제약우   40600.0   6200.0  -13.25%   40300.0   40450.0   241089.0
#
#          거래대금       전일거래량        조회일자  ... 동일업종 PER  동일업종 등락률  \
# 0    111141.0    429312.0  2021-11-25  ...   86.54배    +0.10%
# 1     22445.0   4653164.0  2021-11-25  ...   86.54배    +0.11%
# 2     39313.0   1813404.0  2021-11-25  ...   86.54배    +0.11%
# 3      2737.0     38564.0  2021-11-25  ...   86.54배    +0.10%
# 4     36799.0    457291.0  2021-11-25  ...   86.54배    +0.10%
# ..        ...         ...         ...  ...      ...       ...
# 147      35.0       426.0  2021-11-25  ...   86.54배    +0.11%
# 148    1407.0     41000.0  2021-11-25  ...   86.54배    +0.11%
# 149    2981.0    136664.0  2021-11-25  ...   86.54배    +0.11%
# 150  300126.0  11653906.0  2021-11-25  ...   86.54배    +0.11%
# 151    9720.0    413262.0  2021-11-25  ...   86.54배    +0.08%
#
#      PERlEPS(2021.09)  PBRlBPS (2021.09)  배당수익률l2020.12  PERlEPS(2020.12)  \
# 0                 NaN                NaN            NaN               NaN
# 1       N/A  l  -448원   1.13배  l  5,113원          0.52%               NaN
# 2                 NaN                NaN            NaN       N/A  l  N/A
# 3                 NaN                NaN            NaN     N/A  l  -756원
# 4                 NaN                NaN            NaN               NaN
# ..                ...                ...            ...               ...
# 147      N/A  l  -52원   2.58배  l  6,642원          0.64%               NaN
# 148               NaN                NaN            NaN               NaN
# 149     N/A  l  -404원   2.04배  l  3,671원            NaN               NaN
# 150               NaN                NaN          0.31%               NaN
# 151               NaN                NaN          0.28%               NaN
#
#      PBRlBPS (2020.12)  PERlEPS(2021.08)  PBRlBPS (2021.08)  배당수익률l2020.11
# 0                  NaN               NaN                NaN            NaN
# 1                  NaN               NaN                NaN            NaN
# 2          N/A  l  N/A               NaN                NaN            NaN
# 3      N/A  l  -4,980원               NaN                NaN            NaN
# 4                  NaN               NaN                NaN            NaN
# ..                 ...               ...                ...            ...
# 147                NaN               NaN                NaN            NaN
# 148                NaN               NaN                NaN            NaN
# 149                NaN               NaN                NaN            NaN
# 150                NaN               NaN                NaN            NaN
# 151                NaN               NaN                NaN            NaN
#
# [152 rows x 51 columns]
